# %% [markdown]
# # Install and import dependencies

# %%
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# ...

# %%
pip install transformers

# %%
from transformers import pipeline

# %% [markdown]
# # 2.Setup Generator

# %%
generator = pipeline('text generator')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 generator = pipeline('text generator')
#
# File ~\anaconda3\lib\site-packages\transformers\pipelines\__init__.py:612, in pipeline(task, model, config, tokenizer, feature_extractor, framework, revision, use_fast, use_auth_token, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     608         pipeline_class = get_class_from_dynamic_module(
#     609             model, module_file + ".py", class_name, revision=revision, use_auth_token=use_auth_token
#     610         )
#     611 else:
# --> 612     targeted_task, task_options = check_task(task)
#     613     if pipeline_class is None:
#     614         pipeline_class = targeted_task["impl"]
#
# File ~\anaconda3\lib\site-packages\transformers\pipelines\__init__.py:383, in check_task(task)
# ...

# %%
from transformers import pipeline
from torch.utils.data import Dataset
from tqdm.auto import tqdm

pipe = pipeline("text-classification", device=0)


class MyDataset(Dataset):
    def __len__(self):
        return 5000

    def __getitem__(self, i):
        return "This is a test"


dataset = MyDataset()

for batch_size in [1, 8, 64, 256]:
    print("-" * 30)
    print(f"Streaming batch_size={batch_size}")
    for out in tqdm(pipe(dataset, batch_size=batch_size), total=len(dataset)):
        pass
Copied
# On GTX 970
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [1], in <cell line: 5>()
#       2 from torch.utils.data import Dataset
#       3 from tqdm.auto import tqdm
# ----> 5 pipe = pipeline("text-classification", device=0)
#       8 class MyDataset(Dataset):
#       9     def __len__(self):
#
# File ~\anaconda3\lib\site-packages\transformers\pipelines\__init__.py:767, in pipeline(task, model, config, tokenizer, feature_extractor, framework, revision, use_fast, use_auth_token, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     764 if feature_extractor is not None:
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("gpt2")
model = AutoModelForCausalLM.from_pretrained("gpt2")

prompt = "what is means to be human"
input_ids = tokenizer(prompt, return_tensors="pt").input_ids

# generate up to 30 tokens
outputs = model.generate(input_ids, do_sample=False, max_length=30)
tokenizer.batch_decode(outputs, skip_special_tokens=True)

# %%
pip install gradio

# %%
import gradio as gr

def greet(name):
    return "Hi how are you  " + name + "!"

demo = gr.Interface(fn=greet, inputs="text", outputs="text")
demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860/
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x21180202280>, 'http://127.0.0.1:7860/', None)

# %%
import gradio as gr
from transformers import TFGPT2LMHeadModel, GPT2Tokenizer

# %%
! pip install

# %%
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text

# %%
import pandas as pd

# %%
df = pd.read_excel('new data.xlsx',converters=None)

# %%
df.head()
# Out:
#                         _id   DPCode                  DPName  \
# 0  6163c5abd3fe637f1299f350  HUMS003  Forced Labour Strategy
# 1  6163c5abd3fe637f1299f42c  HUMS003  Forced Labour Strategy
# 2  6163c5abd3fe637f1299f508  HUMS003  Forced Labour Strategy
# 3  6163c66ed3fe637f129a0206  HUMS003  Forced Labour Strategy
# 4  6163c66ed3fe637f129a02e2  HUMS003  Forced Labour Strategy
#
#            CompanyName                    CIN Response       Year  \
# 0  Tata Motors Limited  L28920MH1945PLC004520      Yes  2019-2020
# 1  Tata Motors Limited  L28920MH1945PLC004520      Yes  2018-2019
# 2  Tata Motors Limited  L28920MH1945PLC004520      Yes  2020-2021
# 3        Bosch Limited  L85110KA1951PLC000761      Yes  2019-2020
# 4        Bosch Limited  L85110KA1951PLC000761      Yes  2018-2019
#
#                                   SourceName  \
# 0         Integrated_Annual_Report_2019-2020
# 1         Integrated_Annual_Report_2018-2019
# 2         Integrated_Annual_Report_2020-2021
# ...

# %%
df.to_excel('exceldata.xlsx')

# %%
df.head()
# Out:
#                         _id   DPCode                  DPName  \
# 0  6163c5abd3fe637f1299f350  HUMS003  Forced Labour Strategy
# 1  6163c5abd3fe637f1299f42c  HUMS003  Forced Labour Strategy
# 2  6163c5abd3fe637f1299f508  HUMS003  Forced Labour Strategy
# 3  6163c66ed3fe637f129a0206  HUMS003  Forced Labour Strategy
# 4  6163c66ed3fe637f129a02e2  HUMS003  Forced Labour Strategy
#
#            CompanyName                    CIN Response       Year  \
# 0  Tata Motors Limited  L28920MH1945PLC004520      Yes  2019-2020
# 1  Tata Motors Limited  L28920MH1945PLC004520      Yes  2018-2019
# 2  Tata Motors Limited  L28920MH1945PLC004520      Yes  2020-2021
# 3        Bosch Limited  L85110KA1951PLC000761      Yes  2019-2020
# 4        Bosch Limited  L85110KA1951PLC000761      Yes  2018-2019
#
#                                   SourceName  \
# 0         Integrated_Annual_Report_2019-2020
# 1         Integrated_Annual_Report_2018-2019
# 2         Integrated_Annual_Report_2020-2021
# ...

# %%
df.isnull().sum()
# Out:
# _id             0
# DPCode          0
# DPName          0
# CompanyName     0
# CIN             0
# Response        0
# Year            0
# SourceName      3
# TextSnippet    37
# Respons         0
# dtype: int64

# %%
df[df["TextSnippet"].isnull()]
# Out:
#                            _id   DPCode                  DPName  \
# 44    617aa4209c8adc1741cfa0e6  HUMS003  Forced Labour Strategy
# 45    617aa4219c8adc1741cfa1c2  HUMS003  Forced Labour Strategy
# 65    617b8c2740ba7b1e7a91cbe2  HUMS003  Forced Labour Strategy
# 104   617ce9e52d7ef74b7905d562  HUMS003  Forced Labour Strategy
# 130   617d60612d7ef74b790707b7  HUMS003  Forced Labour Strategy
# 181   617e22e12d7ef74b790ac3b9  HUMS003  Forced Labour Strategy
# 221   618a5578dd7a9d0b143e321d  HUMS003  Forced Labour Strategy
# 222   618a5578dd7a9d0b143e32f9  HUMS003  Forced Labour Strategy
# 223   618a5578dd7a9d0b143e33d5  HUMS003  Forced Labour Strategy
# 237   619644a6c791d202484e4575  HUMS003  Forced Labour Strategy
# 238   619644a7c791d202484e4651  HUMS003  Forced Labour Strategy
# 347   61a88765333b5c265bfa8dc2  HUMS003  Forced Labour Strategy
# 348   61a88766333b5c265bfa8e9d  HUMS003  Forced Labour Strategy
# 349   61a88766333b5c265bfa8f78  HUMS003  Forced Labour Strategy
# ...

# %%
df["TextSnippet"] = df['TextSnippet'].fillna(value=0)

# %%
df.isnull().sum()
# Out:
# _id            0
# DPCode         0
# DPName         0
# CompanyName    0
# CIN            0
# Response       0
# Year           0
# SourceName     3
# TextSnippet    0
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# ['SourceName']

# %%
df["TextSnippet"]
# Out:
# 0       The Human Rights Policy sets out the commitmen...
# 1       The Human Rights Policy sets out the commitmen...
# 2       Human Rights Jaguar Land Roverâ€™s Human Right...
# 3       Forced labor Our business partners reject all ...
# 4       Forced labor Our business partners reject all ...
#                               ...
# 1153    The Company should not use child labour, force...
# 1154    We promote and respect internationally recogni...
# 1155    The Company prohibits forced labour, child lab...
# 1156    The Company shall refrain from employing child...
# 1157                                                   Na
# Name: TextSnippet, Length: 1158, dtype: object

# %%
df.to_csv("DataCOV.csv")

# %%
pip install @tensorflow/tfs @tensorflow-model/qna react-loader-spinner
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '@tensorflow/tfs'

# %%
sentences = [
    "Three years later, the coffin was still full of Jello.",
    "The fish dreamed of escaping the fishbowl and into the toilet where he saw his friend go.",
    "The person box was packed with jelly many dozens of months later.",
    "Three years later, the coffin was still full of Jel.",
    "Three years later, the coffin was still full of Jello.",
]
model_name = 'bert-base-nli-mean-tokens'

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer(model_name)

# %%
sentance = model.encode(sentences)

# %%
sentance.shape
# Out:
# (5, 768)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
read = cosine_similarity([sentance[0]]
                 ,sentance[:-1])

# %%
read
# Out:
# array([[0.9999999 , 0.33088917, 0.7219257 , 0.9523949 ]], dtype=float32)

# %%
import pandas as pd

# %%
df = pd.DataFrame(read)

# %%
df
# Out:
#      0         1         2         3
# 0  1.0  0.330889  0.721926  0.952395

# %%
#Star

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from pprint import pprint

# %%
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# %%
sentences = \
[
    ''''We are working with identified vendors
across locations to enable this, thus diverting our waste from
landfills and contributing to a circular economy. Waste is picked
up by them for further segregation, aggregation and then finally
sent either for recycling or co-processing''',
             
'''Human Rights Jaguar Land Roverâ€™s Human Rights Policy sets out the commitment to respect and comply with all 
relevant laws, rules and regulations in the territories in which Jaguar Land Rover operates. 
These include provisions addressing slavery, human trafficking, forced labour, child labour and 
upholding each employeeâ€™s right to freedom of association. Jaguar Land Rover has refreshed the assessment of
slavery and human trafficking risks related to our operations and continue to deem the risk to be low.
''',
'''The Company shall not use child labour, forced labour 
or any form of Involuntary labour, paid or unpaid.
''',
'''The Company shall refrain from employing child labour, forced labour or any form of involuntary labour, paid or unpaid in any of its offices, units, branches or depots
'''
            ]

# %%
sentence_embeddings = model.encode(sentences)

# %%
for sentence, embedding in zip(sentences, sentence_embeddings):
    print("Sentence:", sentence)
    print("Embedding:", embedding)
# Out:
# Sentence: 'We are working with identified vendors
# across locations to enable this, thus diverting our waste from
# landfills and contributing to a circular economy. Waste is picked
# up by them for further segregation, aggregation and then finally
# sent either for recycling or co-processing
# Embedding: [ 1.35715371e-02  2.86523458e-02 -1.91403944e-02 -3.01289689e-02
#   8.71361196e-02 -7.26334006e-03  5.68223782e-02 -3.99255641e-02
#   5.63328667e-03 -3.52516845e-02  6.41007849e-04  2.15214323e-02
#   3.52469622e-03  6.05533719e-02 -2.44283397e-02 -2.06602756e-02
#   2.28534848e-03  8.90299678e-03 -1.48121128e-02 -1.92370526e-02
#   1.91968540e-03 -3.32652219e-02  1.29429298e-02  3.28098424e-02
#  -2.74736993e-02  4.42138873e-02 -2.39857305e-02 -8.01068246e-02
#   1.03266239e-02 -7.12936074e-02  3.36358207e-03  1.14413910e-01
#  -2.02114470e-02 -1.27813527e-02  1.13858040e-02  5.56050427e-02
#  -3.41363717e-04 -9.00522992e-03  7.45906457e-02 -4.39120680e-02
# ...

# %%
sentence_embeddings.shape
# Out:
# (4, 384)

# %%
pprint('Similarity between:- {}\n and \n{} is \n{}'.format(sentences[0],
       sentences[0],
       cosine_similarity(sentence_embeddings[0].reshape(1, -1),
       sentence_embeddings[1].reshape(1, -1))[0][0]))
# Out:
# ("Similarity between:- 'We are working with identified vendors\n"
#  'across locations to enable this, thus diverting our waste from\n'
#  'landfills and contributing to a circular economy. Waste is picked\n'
#  'up by them for further segregation, aggregation and then finally\n'
#  'sent either for recycling or co-processing\n'
#  ' and \n'
#  "'We are working with identified vendors\n"
#  'across locations to enable this, thus diverting our waste from\n'
#  'landfills and contributing to a circular economy. Waste is picked\n'
#  'up by them for further segregation, aggregation and then finally\n'
#  'sent either for recycling or co-processing is \n'
#  '0.12668728828430176')

# %%
pprint('Similarity between {} and {} is {}'.format(sentences[0],
       sentences[2],
       cosine_similarity(sentence_embeddings[0].reshape(1, -1),
       sentence_embeddings[2].reshape(1, -1))[0][0]))
# Out:
# ("Similarity between 'We are working with identified vendors\n"
#  'across locations to enable this, thus diverting our waste from\n'
#  'landfills and contributing to a circular economy. Waste is picked\n'
#  'up by them for further segregation, aggregation and then finally\n'
#  'sent either for recycling or co-processing and The Company shall not use '
#  'child labour, forced labour \n'
#  'or any form of Involuntary labour, paid or unpaid.\n'
#  ' is 0.07528814673423767')

# %%
pprint('Similarity between {} and {} is {}'.format(sentences[1],
       sentences[2],
       cosine_similarity(sentence_embeddings[2].reshape(1, -1),
       sentence_embeddings[3].reshape(1, -1))[0][0]))
# Out:
# ('Similarity between Human Rights Jaguar Land Roverâ€™s Human Rights Policy '
#  'sets out the commitment to respect and comply with all \n'
#  'relevant laws, rules and regulations in the territories in which Jaguar Land '
#  'Rover operates. \n'
#  'These include provisions addressing slavery, human trafficking, forced '
#  'labour, child labour and \n'
#  'upholding each employeeâ€™s right to freedom of association. Jaguar Land '
#  'Rover has refreshed the assessment of\n'
#  'slavery and human trafficking risks related to our operations and continue '
#  'to deem the risk to be low.\n'
#  ' and The Company shall not use child labour, forced labour \n'
#  'or any form of Involuntary labour, paid or unpaid.\n'
#  ' is 0.8929174542427063')

# %%
from goo

# %%
# !pip install --upgrade tensorflow_text
